# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt   #그래프 출력시
import matplotlib as mpl    #그래프 옵션
import warnings
warnings.filterwarnings('ignore')

import re
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

sns.set_style('darkgrid')

#그래프 시각화 옵션 설정함수
# %matplotlib inline

#그래프의 한글설정
mpl.rc('font',family='Malgun Gothic')

#그래프의 한글을 더욱 선명하게 출력
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

#그래프에서 음수 값이 나올 때, 깨지는 현상 방지
mpl.rc('axes',unicode_minus=False)

# %%
train=pd.read_csv('ratings_train.txt',sep='\t')
test=pd.read_csv('ratings_test.txt',sep='\t')

# %% [markdown]
# # Preprocessing

# %%
train
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [150000 rows x 3 columns]

# %%
train.drop_duplicates(subset = ['document'], inplace=True)
train['document'] = train['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train['document'] = train['document'].replace('', np.nan)
train = train.dropna()

# %%
test.drop_duplicates(subset = ['document'], inplace=True)
test['document'] = test['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
test['document'] = test['document'].replace('', np.nan)
test = test.dropna()

# %%
okt = Okt()
stopwords = ['과','도','를','으로','자','에','와','한','하다','의','가','이','은','들','는','좀','잘']

# %%
X_train = []
for sentence in train['document']:
    temp = []
    temp = okt.morphs(sentence, stem=True) 
    temp = [word for word in temp if not word in stopwords] 
    X_train.append(temp)

# %%
X_test = []
for sentence in test['document']:
    temp = []
    temp = okt.morphs(sentence, stem=True)
    temp = [word for word in temp if not word in stopwords]
    X_test.append(temp)

# %%
Y_train=train['label']

# %%
Y_test=test['label']

# %% [markdown]
# # Tokenize & Padding

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
print(tokenizer.word_index)
# Out:
# {'영화': 1, '보다': 2, '을': 3, '없다': 4, '이다': 5, '있다': 6, '좋다': 7, '너무': 8, '다': 9, '정말': 10, '되다': 11, '재밌다': 12, '적': 13, '만': 14, '같다': 15, '진짜': 16, '로': 17, '아니다': 18, '않다': 19, '점': 20, '에서': 21, '만들다': 22, '나오다': 23, '연기': 24, '것': 25, '평점': 26, '내': 27, '최고': 28, '그': 29, '나': 30, '안': 31, '인': 32, '스토리': 33, '생각': 34, '못': 35, '왜': 36, '드라마': 37, '게': 38, '감동': 39, '사람': 40, '보고': 41, '이렇다': 42, '말': 43, '고': 44, '아깝다': 45, '더': 46, '배우': 47, '때': 48, 'ㅋㅋ': 49, '아': 50, '감독': 51, '거': 52, '그냥': 53, '재미있다': 54, '요': 55, '재미': 56, '시간': 57, '내용': 58, '뭐': 59, '까지': 60, '중': 61, '주다': 62, '자다': 63, '하고': 64, '지루하다': 65, '재미없다': 66, '쓰레기': 67, '수': 68, '네': 69, '모르다': 70, '가다': 71, '들다': 72, '그렇다': 73, '싶다': 74, '지': 75, '작품': 76, '사랑': 77, '알다': 78, '하나': 79, '다시': 80, '마지막': 81, '볼': 82, '이건': 83, '정도': 84, '저': 85, '완전': 86, '오다': 87, 'ㅋ': 88, 'ㅠㅠ': 89, '많다': 90, '처음': 91, 'ㅋㅋㅋ': 92, '장면': 93, '액션': 94, '주인공': 95, '이렇게': 96, '안되다': 97, '걸': 98, '차다': 99, '나다': 100, '개': 101, '하': 102, '최악': 103, '돈': 104, '이야기': 105, '지금': 106, '넘다': 107, '느낌': 108, '임': 109, '연출': 110, 'ㅡㅡ': 111, '라': 112, '인데': 113, '듯': 114, '끝': 115, '명작': 116, '좋아하다': 117, '그리고': 118, '년': 119, '별로': 120, '역시': 121, '받다': 122, '기': 123, '많이': 124, '남다': 125, '별': 126, '이해': 127, '난': 128, '면': 129, '이런': 130, '이영화': 131, '분': 132, '괜찮다': 133, '라고': 134, '느끼다': 135, '또': 136, '버리다': 137, '이나': 138, '때문': 139, '성': 140, '여자': 141, '서': 142, '부터': 143, '먹다': 144, '일': 145, '아름답다': 146, '해주다': 147, '꼭': 148, '보기': 149, '엔': 150, '이고': 151, '두': 152, '무슨': 153, '여': 154, '에게': 155, '기억': 156, '결말': 157, '편': 158, '대': 159, 'ㅎㅎ': 160, '랑': 161, '야': 162, '짱': 163, '아쉽다': 164, '인생': 165, '마음': 166, '영': 167, '소재': 168, '뻔하다': 169, '끄다': 170, '애': 171, '전': 172, '보여주다': 173, '님': 174, '어떻다': 175, '없이': 176, '수준': 177, '어리다': 178, '현실': 179, '무섭다': 180, '맞다': 181, '한번': 182, '속': 183, '씨': 184, '가장': 185, '재다': 186, '급': 187, '본': 188, '웃기다': 189, '반전': 190, '매력': 191, '되어다': 192, '전개': 193, '제': 194, '라는': 195, '한국': 196, '남자': 197, '끝나다': 198, '가슴': 199, '뿐': 200, '낮다': 201, '말다': 202, '아이': 203, '죽다': 204, '슬프다': 205, '높다': 206, '유치하다': 207, '음악': 208, '알': 209, '니': 210, '다른': 211, '멋지다': 212, '원작': 213, '줄': 214, '늘다': 215, '인간': 216, '화': 217, '솔직하다': 218, '크다': 219, '냐': 220, '우리': 221, '추천': 222, '눈물': 223, '쓰다': 224, '살다': 225, '인지': 226, '모든': 227, '지만': 228, '내다': 229, '함': 230, '자체': 231, '번': 232, '야하다': 233, '허다': 234, '눈': 235, '찍다': 236, '하지만': 237, '인가': 238, '캐릭터': 239, '보이다': 240, '코미디': 241, '처럼': 242, 'ㅋㅋㅋㅋ': 243, '대한': 244, '움': 245, '모두': 246, '이상': 247, '뭔가': 248, '대박': 249, 'ㅠ': 250, '돼다': 251, '이네': 252, '전혀': 253, '이쁘다': 254, '연기력': 255, '건지다': 256, '여운': 257, '미치다': 258, '그래도': 259, '짜증나다': 260, '개봉': 261, '공감': 262, '일본': 263, '기대': 264, '기대하다': 265, '시리즈': 266, '근데': 267, '중간': 268, '지다': 269, '표현': 270, '영상': 271, '부분': 272, '아주': 273, '모습': 274, '에는': 275, '작': 276, '제목': 277, '계속': 278, '이랑': 279, '치다': 280, '귀엽다': 281, '이라': 282, '시키다': 283, 'ㅜㅜ': 284, '가족': 285, '내내': 286, '뭔': 287, '보지': 288, '믿다': 289, '진심': 290, '실망': 291, '몰입': 292, '밖에': 293, '후': 294, '짜다': 295, '기분': 296, '대단하다': 297, '연': 298, '작가': 299, '떨어지다': 300, '건': 301, '잔잔하다': 302, 'ㅎ': 303, '이제': 304, '위': 305, '웃다': 306, '요즘': 307, '공포': 308, '빠지다': 309, '스릴러': 310, '이라는': 311, '시': 312, '감': 313, '긴장감': 314, '개인': 315, '용': 316, '잼': 317, '조금': 318, '애니': 319, '대사': 320, '이유': 321, '알바': 322, '특히': 323, '제대로': 324, '삶': 325, '울다': 326, '극장': 327, '점도': 328, '노래': 329, '한테': 330, '딱': 331, '욕': 332, '굿': 333, '점수': 334, '잇다': 335, '시작': 336, '막장': 337, '이란': 338, '나름': 339, '오랜': 340, '이상하다': 341, '극': 342, '이지': 343, '예쁘다': 344, '깊다': 345, '에도': 346, '노잼': 347, '제일': 348, '차라리': 349, '놈': 350, '느껴지다': 351, '친구': 352, '해보다': 353, '영화로': 354, '당시': 355, '같이': 356, '어설프다': 357, '의미': 358, '절대': 359, '빼다': 360, '식': 361, '력': 362, '위해': 363, '류': 364, '세상': 365, '따뜻하다': 366, '찾다': 367, '몇': 368, '아직도': 369, '훌륭하다': 370, '이라고': 371, '년대': 372, '공포영화': 373, '명':  ...

# %%
threshold = 5
total = len(tokenizer.word_index) 
rare = 0 
total_ = 0 
rare_ = 0 


for key, value in tokenizer.word_counts.items():
    total_ = total_ + value

    if(value < threshold):
        rare = rare + 1
        rare_ = rare_ + value

print('단어 집합의 크기 :',total)
print('빈도가 %s번 이하인 희귀 단어 수: %s'%(threshold - 1, rare))
print("집합에서 희귀 단어 비율:", (rare / total)*100)
print("전체 빈도에서 희귀 단어 빈도 비율:", (rare_ / total_)*100)
# Out:
# 단어 집합의 크기 : 43753
# 빈도가 4번 이하인 희귀 단어 수: 29510
# 집합에서 희귀 단어 비율: 67.44680364774986
# 전체 빈도에서 희귀 단어 빈도 비율: 2.9666681040058642

# %%
size = total - rare + 1 
print('단어 집합 크기 :',size)
# Out:
# 단어 집합 크기 : 14244

# %%
tokenizer = Tokenizer(size) 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
drop1 = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]
drop2 = [index for index, sentence in enumerate(X_test) if len(sentence) < 1]

# %%
Y_train = np.array(Y_train)
Y_test = np.array(Y_test)

# %%
X_train = np.delete(X_train, drop1, axis=0)
Y_train = np.delete(Y_train, drop1, axis=0)
X_test = np.delete(X_test, drop2, axis=0)
Y_test = np.delete(Y_test, drop2, axis=0)

# %%
print('Max length :',max(len(l) for l in X_train))
print('Mean length :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)

plt.xlabel('length')
plt.ylabel('count')
plt.show()
# Out:
# Max length : 69
# Mean length : 10.702271818695634

# %%
def under(max_len, list):
    a = 0
    for s in list:
        if(len(s) <= max_len):
            a = a + 1
    print('길이가 %s 이하인 비율: %s'%(max_len, (a / len(list))*100))

# %%
max_len = 25
under(max_len, X_train)
# Out:
# 길이가 25 이하인 비율: 91.93145945051764

# %%
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
X_train
# Out:
# array([[    0,     0,     0, ...,    16,   260,   660],
#        [    0,     0,     0, ...,   962,   676,    19],
#        [    0,     0,     0, ...,     2,   222,     9],
#        ...,
#        [    0,     0,     0, ..., 10466, 10402,  1044],
#        [    0,     0,     0, ...,  1225,   541,  7849],
#        [    0,     0,     0, ...,    58,  1358,     1]])

# %% [markdown]
# # Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# %% [markdown]
# ## RandomForest

# %%
rf=RandomForestClassifier(random_state=1234)
rf.fit(X_train,Y_train)
pred=rf.predict(X_test)
accuracy_score(Y_test,pred)
# Out:
# 0.6085626911314985

# %% [markdown]
# ## XGB

# %%
xgb=XGBClassifier(random_state=1234)
xgb.fit(X_train,Y_train)
pred=xgb.predict(X_test)
accuracy_score(Y_test,pred)
# Out:
# 0.7307842292141289

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(Embedding(size, 100))
model.add(LSTM(256))
Dropout(0.3)
model.add(Dense(1, activation='sigmoid'))

# %%
early = EarlyStopping(monitor='val_loss', verbose=1, patience=5)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, Y_train, epochs=20, callbacks=[early], batch_size=100, validation_split=0.2, workers=0, use_multiprocessing=True)
# Out:
# Train on 116065 samples, validate on 29017 samples
# Epoch 1/20
# 116065/116065 [==============================] - 97s 833us/sample - loss: 0.3583 - acc: 0.8410 - val_loss: 0.3481 - val_acc: 0.8476
# Epoch 2/20
# 116065/116065 [==============================] - 95s 822us/sample - loss: 0.3184 - acc: 0.8626 - val_loss: 0.3348 - val_acc: 0.8544
# Epoch 3/20
# 116065/116065 [==============================] - 94s 811us/sample - loss: 0.2966 - acc: 0.8739 - val_loss: 0.3356 - val_acc: 0.8585
# Epoch 4/20
# 116065/116065 [==============================] - 93s 803us/sample - loss: 0.2792 - acc: 0.8833 - val_loss: 0.3309 - val_acc: 0.8596
# Epoch 5/20
# 116065/116065 [==============================] - 93s 801us/sample - loss: 0.2636 - acc: 0.8912 - val_loss: 0.3326 - val_acc: 0.8578
# Epoch 6/20
# 116065/116065 [==============================] - 92s 795us/sample - loss: 0.2478 - acc: 0.8992 - val_loss: 0.3484 - val_acc: 0.8567
# Epoch 7/20
# 116065/116065 [==============================] - 92s 795us/sample - loss: 0.2313 - acc: 0.9070 - val_loss: 0.3495 - val_acc: 0.8548
# Epoch 8/20
# 116065/116065 [==============================] - 94s 814us/sample - loss: 0.2145 - acc: 0.9154 - val_loss: 0.3710 - val_acc: 0.8464
# Epoch 9/20
# 116065/116065 [==============================] - 93s 802us/sample - loss: 0.1969 - acc: 0.9230 - val_loss: 0.3843 - val_acc: 0.8454
# Epoch 00009: early stopping

# %%
model.evaluate(X_test,Y_test)[1]
# Out:
# 48723/48723 [==============================] - 25s 516us/sample - loss: 0.3863 - acc: 0.8459
# 0.8459249

# %% [markdown]
# ## 아래 코드는 Sample 파일 Labeling을 위한 코드

# %%
new_X_test_ = list(pd.read_csv("""D:\\PythonWorkspace\\Support\\emotion\\ko_sample\\ko_data.csv""", encoding='cp949')['Sentence'])

# %%
new_X_test = tokenizer.texts_to_sequences(new_X_test_)

# %%
new_X_test = pad_sequences(new_X_test)

# %%
new_X_test
# Out:
# array([[   0,    0,    0, ...,    0,   10,  124],
#        [   0,    0,    0, ...,    0,    0,   57],
#        [   0,    0,    0, ...,    0,    0,   74],
#        ...,
#        [   0,    0,    0, ...,   31,  700,  376],
#        [   0,    0,    0, ...,    0,    0, 4446],
#        [   0,    0,    0, ...,    0,    0,    0]])

# %%
pred = model.predict_classes(new_X_test)

# %%
len(pred)
# Out:
# 11187

# %%
result = pd.DataFrame(pred, columns=['Predicted']).reset_index().rename(columns={'index': 'Id'''})

# %%
result
# Out:
#           Id  Predicted
# 0          0          0
# 1          1          0
# 2          2          0
# 3          3          1
# 4          4          0
# ...      ...        ...
# 11182  11182          1
# 11183  11183          0
# 11184  11184          0
# 11185  11185          1
# 11186  11186          1
#
# [11187 rows x 2 columns]

# %%
result.to_csv("""D:\\PythonWorkspace\\Support\\emotion\\ko_sample\\result_ko.csv""", index=False)
